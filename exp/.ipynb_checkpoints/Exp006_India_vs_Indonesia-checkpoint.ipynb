# %% [markdown]
# ### India vs Indonesia
#
# Since we found out that Indonesia had a similar food insecurity issue as India at the start of the century but was able to solve it in a much better way than India, we drill down on how to individual features have changed for both of these countries over time.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
font = {
    'size': 15
}
matplotlib.rc('font', **font)

# %%
# Data for all the conflicts in the world.
base_dataset = pd.read_csv('../data/gedevents-2022-02-02.csv', index_col=False)

# %%
base_dataset = base_dataset[
    base_dataset['year'] >= 2000
]
columns_to_keep = [
    'country', 'year', 'type_of_violence', 'best_est'
]
base_dataset = base_dataset[columns_to_keep]

# %%
# The dataset we created in Exp3
faostat_dataset = pd.read_csv('../data/final_dataset.csv')
food_insecurity_df = faostat_dataset[
    (faostat_dataset["Country"].isin(["India", "Indonesia"]))
    & (faostat_dataset["Year"].between(2000, 2019))
][["Country", "Year", "UndernourishedPercent"]]
food_insecurity_df
# Out:
#          Country  Year UndernourishedPercent
# 5450   Indonesia  2000                   NaN
# 5451   Indonesia  2001                  19.2
# 5452   Indonesia  2002                  19.1
# 5453   Indonesia  2003                  18.9
# 5454   Indonesia  2004                  19.1
# 5455   Indonesia  2005                  19.2
# 5456   Indonesia  2006                    19
# 5457   Indonesia  2007                  18.5
# 5458   Indonesia  2008                  17.4
# 5459   Indonesia  2009                  15.5
# 5460   Indonesia  2010                    13
# 5461   Indonesia  2011                  10.7
# 5462   Indonesia  2012                   9.4
# 5463   Indonesia  2013                   8.3
# 5464   Indonesia  2014                   7.7
# 5465   Indonesia  2015                     7
# 5466   Indonesia  2016                   6.8
# 5467   Indonesia  2017                   6.4
# 5468   Indonesia  2018                   6.4
# 5469   Indonesia  2019                   6.5
# ...

# %%
base_dataset
# Out:
#       country  year  type_of_violence  best_est
# 0       India  2000                 1         3
# 3       India  2003                 1         2
# 4       India  2012                 1         1
# 5       India  2003                 1         1
# 6       India  2003                 1         2
# ...       ...   ...               ...       ...
# 17413   India  2019                 1         3
# 17414   India  2019                 1         1
# 17415   India  2019                 1         2
# 17416   India  2019                 1         1
# 17417   India  2019                 1         1
#
# [13821 rows x 4 columns]

# %%
bins = np.arange(1999, 2021, 5)
cumulative_conflicts = base_dataset.groupby(
    ['country', 'type_of_violence', pd.cut(base_dataset.year, bins)]
).sum().drop('year', axis=1)

# %%
cumulative_conflicts
# Out:
#                                          best_est
# country   type_of_violence year
# India     1                (1999, 2004]      8861
#                            (2004, 2009]      6357
#                            (2009, 2014]      2952
#                            (2014, 2019]      3286
#           2                (1999, 2004]       339
#                            (2004, 2009]       366
#                            (2009, 2014]       263
#                            (2014, 2019]        14
#           3                (1999, 2004]      3404
#                            (2004, 2009]      2636
#                            (2009, 2014]      1461
#                            (2014, 2019]       620
# Indonesia 1                (1999, 2004]      2834
#                            (2004, 2009]       228
#                            (2009, 2014]        32
#                            (2014, 2019]        42
#           2                (1999, 2004]      1075
# ...

# %%
# Creating a graph comparing deaths in India and Indonesia due to conflicts and correlating with their
# percentage of undernourished people over time
x_labels = cumulative_conflicts.index.unique(level='year').values.astype(str)
x_axis_1 = np.asarray([2001.5, 2006.5, 2011.5, 2016.5])
x_axis_2 = np.arange(2000, 2020, 1)
width = 2

fig, ax = plt.subplots(figsize=(15, 10))
y_axis_india_1 = cumulative_conflicts.loc['India', 1]['best_est'].values
y_axis_india_2 = cumulative_conflicts.loc['India', 2]['best_est'].values
y_axis_india_3 = cumulative_conflicts.loc['India', 3]['best_est'].values
y_axis_indonesia_1 = cumulative_conflicts.loc['Indonesia', 1]['best_est'].values
y_axis_indonesia_2 = cumulative_conflicts.loc['Indonesia', 2]['best_est'].values
y_axis_indonesia_3 = cumulative_conflicts.loc['Indonesia', 3]['best_est'].values

colors_indonesia = plt.cm.Blues(np.linspace(0.2, 0.6, 3))
colors_india = plt.cm.OrRd(np.linspace(0.2, 0.5, 3))

alpha_bar = 1
plt1 = ax.bar(
    x_axis_1 - 0.52*width,
    y_axis_india_1,
    width,
    label="India - State-Based Violence",
    alpha=alpha_bar,
    color=colors_india[2]
)
plt2 = ax.bar(
    x_axis_1 - 0.52*width,
    y_axis_india_2,
    width,
    bottom = y_axis_india_1,
    label="India - Non-State Violence",
    alpha=alpha_bar,
    color=colors_india[1]
)
plt3 = ax.bar(
    x_axis_1 - 0.52*width,
    y_axis_india_3,
    width,
    bottom = y_axis_india_1 + y_axis_india_2,
    label="India - One-Sided Violence",
    alpha=alpha_bar,
    color=colors_india[0]
)
plt4 = ax.bar(
    x_axis_1 + 0.52*width,
    y_axis_indonesia_1,
    width,
    label="Indonesia - State-Based Violence",
    alpha=alpha_bar,
    color=colors_indonesia[2]
)
plt5 = ax.bar(
    x_axis_1 + 0.52*width,
    y_axis_indonesia_2,
    width,
    bottom = y_axis_indonesia_1,
    label="Indonesia - Non-State Violence",
    alpha=alpha_bar,
    color=colors_indonesia[1]
)
plt6 = ax.bar(
    x_axis_1 + 0.52*width,
    y_axis_indonesia_3,
    width,
    bottom = y_axis_indonesia_1 + y_axis_indonesia_2,
    label="Indonesia - One-Sided Violence",
    alpha=alpha_bar,
    color=colors_indonesia[0]
)


ax.bar_label(plt3, padding = 2)
ax.bar_label(plt6, padding = 2)

ax.set_ylabel("Number of Casualties")
# ax.set_xlabel("Timeline (left: India, right: Indonesia)")
plt.xticks(x_axis_1, x_labels)

ax2 = ax.twinx()
ax2.set_ylabel('Prevalance of Undernourishment (PoU) (%)', labelpad=15)

india_undernourished = food_insecurity_df[food_insecurity_df["Country"] == "India"]
indonesia_undernourished = food_insecurity_df[food_insecurity_df["Country"] == "Indonesia"]

line_width = 4
plt7 = ax2.plot(
    x_axis_2,
    india_undernourished["UndernourishedPercent"],
    label="India = PoU",
    linewidth=line_width,
    color = 'lightcoral'
)
plt8 = ax2.plot(
    x_axis_2,
    indonesia_undernourished["UndernourishedPercent"],
    label="Indonesia = PoU",
    linewidth=line_width,
    color = 'steelblue'
)

# Processing for legend
lns = [plt1] + [plt2] + [plt3] + [plt4] + [plt5] + [plt6] + plt7 + plt8
labels = [l.get_label() for l in lns]
ax.legend(lns, labels)
plt.title(
    'Conflict-Related Fatalities vs Prevalence of Undernourishment (PoU) in India (Orange) and Indonesia (Blue)',
    pad=20)
plt.show()

# %% [markdown]
# # Unemployment

# %%
# Fetching unemployment data sourced from the world bank publicly available data
unemployment_dataset = pd.read_csv('../data/Unemployment_India_Indonesia_World_Bank_Data.csv')
unemployment_dataset.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
unemployment_dataset.loc[2]['Series Name']
# Out:
# 'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)'

# %%
unemployment_total_df = unemployment_dataset[
    (unemployment_dataset['Series Name'] == 'Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)')
].drop(columns=['Series Name', 'Series Code', 'Country Code', '2020 [YR2020]'])
unemployment_total_df.set_index('Country', inplace=True)

# %%
food_inflation_df = faostat_dataset[
    (faostat_dataset['Country'].isin(['India', 'Indonesia']))
    & (faostat_dataset['Year'].between(2000, 2019))
][['Country', 'Year', 'FoodInflation', 'PurchasingPower']].reset_index(drop=True)
food_inflation_df.set_index(['Country', 'Year'], inplace=True)

# %%
# Trying to find correlation between the unemployment and food inflation
food_inflation_df_india = food_inflation_df.loc['India']
food_inflation_df_indonesia = food_inflation_df.loc['Indonesia']
plt.scatter(
    food_inflation_df_indonesia['FoodInflation'],
    unemployment_total_df.loc['Indonesia'].values,
    label='Indonesia',
    color='steelblue'
)
plt.ylabel('Unemployment rate')
plt.xlabel('Food Inflation rate')
plt.legend()
plt.show()

# %%
# Plotting Unemployment % vs GDP-PPP for both the countries and comparing the trends
food_inflation_df_india = food_inflation_df.loc['India']
food_inflation_df_indonesia = food_inflation_df.loc['Indonesia']
fig, ax = plt.subplots(1, 2, figsize=(15,7))


x0 = food_inflation_df_india['PurchasingPower']
x1 = food_inflation_df_indonesia['PurchasingPower']

ax[0].scatter(x0, unemployment_total_df.loc['India'].values, label='India', color='lightcoral')
ax[1].scatter(x1, unemployment_total_df.loc['Indonesia'].values, label='Indonesia', color='steelblue')

m0, b0 = np.polyfit(x0, unemployment_total_df.loc['India'].values, 1)
m1, b1 = np.polyfit(x1, unemployment_total_df.loc['Indonesia'].values, 1)
ax[0].plot(x0, m0*x0 + b0, color='lightcoral', linestyle='--')
ax[1].plot(x1, m1*x1 + b1, color='steelblue', linestyle='--')

ax[0].set_ylabel('Youth Unemployment Rate (%)')
fig.text(0.5, 0.03, 'GDP Per Capita Adjusted for PPP (USD)', ha='center')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
# Plotting GDP per capita adjusted for PPP for India and Indonesia over time
x_axis = np.arange(2000, 2020, 1)
fig = plt.figure(figsize=(15,10))
plt.plot(
    x_axis,
    food_inflation_df.loc['India']['PurchasingPower'],
    label='India',
    color='lightcoral',
    linewidth=5
)
plt.plot(
    x_axis,
    food_inflation_df.loc['Indonesia']['PurchasingPower'],
    label='Indonesia',
    color='steelblue',
    linewidth=5
)
plt.xlabel('Time (Years)')
plt.ylabel('GDP Per Capita adjusted for PPP (USD)')
plt.xticks(x_axis[::2])
plt.title('GDP Per Capita adjusted for PPP over time', pad=15)
plt.grid()

plt.legend()
plt.show()
